# %%
#Import Modules
import pandas as pd
import seaborn as sns

# %%
#Import Data
df = pd.read_csv(r'Flights.csv')
df.head()
print(df)
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
#Create visualization
sns.relplot(data=df, x='year', y='passengers', hue='month')
